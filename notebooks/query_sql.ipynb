# %% [markdown]
# # Importar Biblioteca

# %%
import duckdb

# %% [markdown]
# # Conexão com DuckDB

# %%
conexao = duckdb.connect('../dados/filme_duckdb.db')

# %% [markdown]
# # Listar todas as tabelas do BD

# %%
query = " SHOW TABLES "
resultado = conexao.execute(query).fetchall()
print(resultado)
# Out:
# [('countries',), ('directors',), ('filmes',), ('filmes_countries',), ('filmes_directors',), ('filmes_genres',), ('filmes_imdb',), ('filmes_languages',), ('filmes_locations',), ('filmes_stars',), ('filmes_writers',), ('genres',), ('languages',), ('locations',), ('stars',), ('writers',)]

# %% [markdown]
# # Listar dados originais

# %%
query = 'SELECT * FROM filmes_imdb;'
df = conexao.execute(query).fetchdf()
df.head(5)
# Out:
#           id                            Title  \
# 0  tt0073195                             Jaws
# 1  tt0073629    The Rocky Horror Picture Show
# 2  tt0073486  One Flew Over the Cuckoo's Nest
# 3  tt0072890                Dog Day Afternoon
# 4  tt0073692                          Shampoo
#
#                              Movie Link  Year Duration MPA  Rating Votes  \
# 0  https://www.imdb.com/title/tt0073195  1975    2h 4m  PG     8.1  683K
# 1  https://www.imdb.com/title/tt0073629  1975   1h 40m   R     7.4  173K
# 2  https://www.imdb.com/title/tt0073486  1975   2h 13m   R     8.7  1.1M
# 3  https://www.imdb.com/title/tt0072890  1975    2h 5m   R     8.0  279K
# 4  https://www.imdb.com/title/tt0073692  1975   1h 50m   R     6.4   15K
#
#       budget  grossWorldWide  ...  \
# 0  7000000.0     477220580.0  ...
# 1  1200000.0     115798478.0  ...
# 2  3000000.0     109115366.0  ...
# 3  1800000.0      50002721.0  ...
# 4  4000000.0      49407734.0  ...
#
# ...

# %%
# descrição dos dados
df.describe()
# Out:
#                Year        Rating        budget  grossWorldWide  \
# count  33600.000000  33462.000000  1.181500e+04    1.822200e+04
# mean    1992.393631      6.155158  8.454320e+07    3.814961e+07
# std       18.957395      1.146070  2.866281e+09    1.210105e+08
# min     1960.000000      1.100000  1.000000e+00    1.000000e+00
# 25%     1976.000000      5.500000  2.000000e+06    1.589938e+05
# 50%     1993.000000      6.300000  9.000000e+06    2.311544e+06
# 75%     2009.000000      7.000000  2.700000e+07    2.092931e+07
# max     2024.000000      9.600000  3.000000e+11    2.923706e+09
#
#        gross_US_Canada  opening_weekend_Gross     wins   nominations  \
# count     1.757100e+04           1.552300e+04  33600.0  33600.000000
# mean      1.808236e+07           5.110082e+06      0.0      4.850357
# std       4.853181e+07           1.488319e+07      0.0     17.719188
# min       6.400000e+01           1.100000e+01      0.0      0.000000
# ...

# %%
# informações sobre os dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33600 entries, 0 to 33599
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     33600 non-null  object
#  1   Title                  33600 non-null  object
#  2   Movie Link             33600 non-null  object
#  3   Year                   33600 non-null  int64
#  4   Duration               33379 non-null  object
#  5   MPA                    25624 non-null  object
#  6   Rating                 33462 non-null  float64
#  7   Votes                  33462 non-null  object
#  8   budget                 11815 non-null  float64
#  9   grossWorldWide         18222 non-null  float64
#  10  gross_US_Canada        17571 non-null  float64
#  11  opening_weekend_Gross  15523 non-null  float64
#  12  directors              33241 non-null  object
#  13  writers                32024 non-null  object
# ...

# %%
# nome das colunas
df.columns
# Out:
# Index(['id', 'Title', 'Movie Link', 'Year', 'Duration', 'MPA', 'Rating',
#        'Votes', 'budget', 'grossWorldWide', 'gross_US_Canada',
#        'opening_weekend_Gross', 'directors', 'writers', 'stars', 'genres',
#        'countries_origin', 'filming_locations', 'production_companies',
#        'Languages', 'wins', 'nominations', 'oscars'],
#       dtype='object')

# %%
# quantidade de linhas e colunas
df.shape
# Out:
# (33600, 23)

# %%
#Filtrando dados
# SELECT * FROM filmes_imdb WHERE Votes = '279K';
df_filtrado = df[df['Votes'] == '279K']
df_filtrado
# Out:
#               id                        Title  \
# 3      tt0072890            Dog Day Afternoon
# 2714   tt1931533            Seven Psychopaths
# 6250   tt0363547             Dawn of the Dead
# 8955   tt0102057                         Hook
# 21225  tt0327597                     Coraline
# 22752  tt7097896  Venom: Let There Be Carnage
#
#                                  Movie Link  Year Duration    MPA  Rating  \
# 3      https://www.imdb.com/title/tt0072890  1975    2h 5m      R     8.0
# 2714   https://www.imdb.com/title/tt1931533  2012   1h 50m      R     7.1
# 6250   https://www.imdb.com/title/tt0363547  2004   1h 41m      R     7.2
# 8955   https://www.imdb.com/title/tt0102057  1991   2h 22m     PG     6.8
# 21225  https://www.imdb.com/title/tt0327597  2009   1h 40m     PG     7.8
# 22752  https://www.imdb.com/title/tt7097896  2021   1h 37m  PG-13     5.9
#
#       Votes       budget  grossWorldWide  ...  \
# 3      279K    1800000.0      50002721.0  ...
# ...

# %% [markdown]
# # Consultas do arquivo query.sql

# %% [markdown]
# ### Consultar filmes genero drama

# %%
query = "SELECT * FROM filmes_imdb WHERE genres LIKE '%Drama%'"
df_drama = conexao.execute(query).fetchdf()
df_drama.head()
# Out:
#           id                            Title  \
# 0  tt0073195                             Jaws
# 1  tt0073486  One Flew Over the Cuckoo's Nest
# 2  tt0072890                Dog Day Afternoon
# 3  tt0073692                          Shampoo
# 4  tt0073026                       Funny Lady
#
#                              Movie Link  Year Duration MPA  Rating Votes  \
# 0  https://www.imdb.com/title/tt0073195  1975    2h 4m  PG     8.1  683K
# 1  https://www.imdb.com/title/tt0073486  1975   2h 13m   R     8.7  1.1M
# 2  https://www.imdb.com/title/tt0072890  1975    2h 5m   R     8.0  279K
# 3  https://www.imdb.com/title/tt0073692  1975   1h 50m   R     6.4   15K
# 4  https://www.imdb.com/title/tt0073026  1975   2h 16m  PG     6.2  6.1K
#
#       budget  grossWorldWide  ...  \
# 0  7000000.0     477220580.0  ...
# 1  3000000.0     109115366.0  ...
# 2  1800000.0      50002721.0  ...
# 3  4000000.0      49407734.0  ...
# 4        NaN      39000000.0  ...
#
# ...

# %% [markdown]
# ### Consultar filmes ano 2024

# %%
query = "SELECT * FROM filmes_imdb WHERE  Year = '2024'"
df_2024 = conexao.execute(query).fetchdf()
df_2024.head()
# Out:
#            id                 Title                             Movie Link  \
# 0  tt22022452          Inside Out 2  https://www.imdb.com/title/tt22022452
# 1   tt6263850  Deadpool & Wolverine   https://www.imdb.com/title/tt6263850
# 2   tt1262426                Wicked   https://www.imdb.com/title/tt1262426
# 3  tt13622970               Moana 2  https://www.imdb.com/title/tt13622970
# 4   tt7510222       Despicable Me 4   https://www.imdb.com/title/tt7510222
#
#    Year Duration MPA  Rating Votes       budget  grossWorldWide  ...  \
# 0  2024   1h 36m  PG     7.6  194K  200000000.0    1.698773e+09  ...
# 1  2024    2h 8m   R     7.6  441K  200000000.0    1.338074e+09  ...
# 2  2024   2h 40m  PG     7.9   90K  150000000.0    6.547759e+08  ...
# 3  2024   1h 40m  PG     7.0   56K  150000000.0    9.134555e+08  ...
# 4  2024   1h 34m  PG     6.2   55K  100000000.0    9.691265e+08  ...
#
#                                              writers  \
# ...

# %%
df2024 = df[df['Year']== 2024]
df2024.head()
# Out:
#               id                 Title                             Movie Link  \
# 8350  tt22022452          Inside Out 2  https://www.imdb.com/title/tt22022452
# 8351   tt6263850  Deadpool & Wolverine   https://www.imdb.com/title/tt6263850
# 8352   tt1262426                Wicked   https://www.imdb.com/title/tt1262426
# 8353  tt13622970               Moana 2  https://www.imdb.com/title/tt13622970
# 8354   tt7510222       Despicable Me 4   https://www.imdb.com/title/tt7510222
#
#       Year Duration MPA  Rating Votes       budget  grossWorldWide  ...  \
# 8350  2024   1h 36m  PG     7.6  194K  200000000.0    1.698773e+09  ...
# 8351  2024    2h 8m   R     7.6  441K  200000000.0    1.338074e+09  ...
# 8352  2024   2h 40m  PG     7.9   90K  150000000.0    6.547759e+08  ...
# 8353  2024   1h 40m  PG     7.0   56K  150000000.0    9.134555e+08  ...
# 8354  2024   1h 34m  PG     6.2   55K  100000000.0    9.691265e+08  ...
#
#                                                 writers  \
# ...

# %% [markdown]
# ### Consultar filmes com buget maior que 5000000

# %%
df_budget = df[df['budget'] > 5000000]
df_budget.head()
# Out:
#            id                     Title                            Movie Link  \
# 0   tt0073195                      Jaws  https://www.imdb.com/title/tt0073195
# 9   tt0073802  Three Days of the Condor  https://www.imdb.com/title/tt0073802
# 10  tt0073317                Lucky Lady  https://www.imdb.com/title/tt0073317
# 15  tt0072926        The Eiger Sanction  https://www.imdb.com/title/tt0072926
# 22  tt0072665         At Long Last Love  https://www.imdb.com/title/tt0072665
#
#     Year Duration MPA  Rating Votes      budget  grossWorldWide  ...  \
# 0   1975    2h 4m  PG     8.1  683K   7000000.0     477220580.0  ...
# 9   1975   1h 57m   R     7.4   65K  20000000.0      27476252.0  ...
# 10  1975   1h 58m  PG     5.2  1.4K  13000000.0      24441725.0  ...
# 15  1975    2h 9m   R     6.4   23K   9000000.0      14200000.0  ...
# 22  1975   1h 58m   G     5.3  1.4K   6000000.0       1500000.0  ...
#
#                                               writers  \
# ...

# %% [markdown]
# ### Consultar filmes com ator vin diesel

# %%
df_stars = df[df['stars'].str.contains('in diesel', case=False, na=False)]
df_stars.head()
# Out:
#              id                       Title  \
# 2026  tt1634106                   Bloodshot
# 3111  tt4630562     The Fate of the Furious
# 3161  tt1293847  xXx: Return of Xander Cage
# 3655  tt1596343                   Fast Five
# 6254  tt0296572   The Chronicles of Riddick
#
#                                 Movie Link  Year Duration    MPA  Rating  \
# 2026  https://www.imdb.com/title/tt1634106  2020   1h 49m  PG-13     5.7
# 3111  https://www.imdb.com/title/tt4630562  2017   2h 16m  PG-13     6.6
# 3161  https://www.imdb.com/title/tt1293847  2017   1h 47m  PG-13     5.2
# 3655  https://www.imdb.com/title/tt1596343  2011   2h 10m  PG-13     7.3
# 6254  https://www.imdb.com/title/tt0296572  2004   1h 59m      R     6.6
#
#      Votes       budget  grossWorldWide  ...  \
# 2026   87K   45000000.0    3.986112e+07  ...
# 3111  261K  250000000.0    1.236009e+09  ...
# 3161   99K   85000000.0    3.461183e+08  ...
# 3655  416K  125000000.0    6.261400e+08  ...
# ...

# %% [markdown]
# ### Pesquisar apenas filmes com origem no Canadá:

# %%
df_countries = df[df['countries_origin'].str.contains('Canada', case=False, na=False)]
df_countries.head()
# Out:
#            id                     Title                            Movie Link  \
# 37  tt0071650  Ilsa: She Wolf of the SS  https://www.imdb.com/title/tt0071650
# 42  tt0073115            The Story of O  https://www.imdb.com/title/tt0073115
# 44  tt0073631                Rollerball  https://www.imdb.com/title/tt0073631
# 49  tt0073705                   Shivers  https://www.imdb.com/title/tt0073705
# 66  tt0072184                     Snuff  https://www.imdb.com/title/tt0072184
#
#     Year Duration    MPA  Rating Votes     budget  grossWorldWide  ...  \
# 37  1975   1h 36m      R     5.1  8.4K        NaN             NaN  ...
# 42  1975   1h 37m  NC-17     5.3  7.1K        NaN             NaN  ...
# 44  1975    2h 5m      R     6.5   30K  6000000.0             NaN  ...
# 49  1975   1h 27m      R     6.3   24K   185000.0             NaN  ...
# 66  1975   1h 20m      X     2.8  2.1K        NaN             NaN  ...
#
#                                      writers  \
# ...

# %% [markdown]
# ### Pesquisar apenas filmes em inglês:

# %%
df_languages = df[df['Languages'].str.contains('English', case=False, na=False)]
df_languages.head()
# Out:
#           id                            Title  \
# 0  tt0073195                             Jaws
# 1  tt0073629    The Rocky Horror Picture Show
# 2  tt0073486  One Flew Over the Cuckoo's Nest
# 3  tt0072890                Dog Day Afternoon
# 4  tt0073692                          Shampoo
#
#                              Movie Link  Year Duration MPA  Rating Votes  \
# 0  https://www.imdb.com/title/tt0073195  1975    2h 4m  PG     8.1  683K
# 1  https://www.imdb.com/title/tt0073629  1975   1h 40m   R     7.4  173K
# 2  https://www.imdb.com/title/tt0073486  1975   2h 13m   R     8.7  1.1M
# 3  https://www.imdb.com/title/tt0072890  1975    2h 5m   R     8.0  279K
# 4  https://www.imdb.com/title/tt0073692  1975   1h 50m   R     6.4   15K
#
#       budget  grossWorldWide  ...  \
# 0  7000000.0     477220580.0  ...
# 1  1200000.0     115798478.0  ...
# 2  3000000.0     109115366.0  ...
# 3  1800000.0      50002721.0  ...
# 4  4000000.0      49407734.0  ...
#
# ...

# %% [markdown]
# ### Consultar filmes com duração superior a 2 horas

# %%
df_duration = df[df['Duration'] > 2]
df_duration.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df_duration = df[df['Duration'] > 2]
#       2 df_duration.head()
#
# File c:\ProfDaniloSantos\Python\projeto-filme\venv\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\ProfDaniloSantos\Python\projeto-filme\venv\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File c:\ProfDaniloSantos\Python\projeto-filme\venv\Lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
# ...

# %% [markdown]
# ### Consultar filmes que tiveram uma nota maior que 6

# %%
df_rating = df[df['Rating'] > 6]
df_rating.head()
# Out:
#           id                            Title  \
# 0  tt0073195                             Jaws
# 1  tt0073629    The Rocky Horror Picture Show
# 2  tt0073486  One Flew Over the Cuckoo's Nest
# 3  tt0072890                Dog Day Afternoon
# 4  tt0073692                          Shampoo
#
#                              Movie Link  Year Duration MPA  Rating Votes  \
# 0  https://www.imdb.com/title/tt0073195  1975    2h 4m  PG     8.1  683K
# 1  https://www.imdb.com/title/tt0073629  1975   1h 40m   R     7.4  173K
# 2  https://www.imdb.com/title/tt0073486  1975   2h 13m   R     8.7  1.1M
# 3  https://www.imdb.com/title/tt0072890  1975    2h 5m   R     8.0  279K
# 4  https://www.imdb.com/title/tt0073692  1975   1h 50m   R     6.4   15K
#
#       budget  grossWorldWide  ...  \
# 0  7000000.0     477220580.0  ...
# 1  1200000.0     115798478.0  ...
# 2  3000000.0     109115366.0  ...
# 3  1800000.0      50002721.0  ...
# 4  4000000.0      49407734.0  ...
#
# ...

# %% [markdown]
# ### Consultar filme dos anos 2024 e 2h 40m

# %%
df_duration2 = df[(df['Year'] == 2024) & (df['Duration'] == '2h 40m')]
df_duration2.head()
# Out:
#               id    Title                             Movie Link  Year  \
# 8352   tt1262426   Wicked   https://www.imdb.com/title/tt1262426  2024
# 8800  tt29120307  Vanvaas  https://www.imdb.com/title/tt29120307  2024
#
#      Duration   MPA  Rating Votes       budget  grossWorldWide  ...  \
# 8352   2h 40m    PG     7.9   90K  150000000.0     654775945.0  ...
# 8800   2h 40m  None     6.8   550          NaN         18172.0  ...
#
#                                                 writers  \
# 8352  ['Winnie Holzman', 'Dana Fox', 'Gregory Maguire']
# 8800     ['Amjad Ali', 'Anil Sharma', 'Sunil Sirvaiya']
#
#                                                   stars  \
# 8352  ['Cynthia Erivo', 'Ariana Grande', 'Jeff Goldb...
# 8800  ['Nana Patekar', 'Ashwini Kalsekar', 'Rajpal N...
#
#                                                  genres  \
# 8352  ['Fairy Tale', 'Pop Musical', 'Fantasy', 'Musi...
# 8800                                ['Action', 'Drama']
#
# ...

# %% [markdown]
# ### Consultar filmes produzidos pela Disney

# %%
df_production = df[df['production_companies'].str.contains('Walt Disney Pictures', case=False, na=False)]
df_production.head()
# Out:
#               id        Title                             Movie Link  Year  \
# 2007   tt7146812       Onward   https://www.imdb.com/title/tt7146812  2020
# 2067   tt2948372         Soul   https://www.imdb.com/title/tt2948372  2020
# 2274   tt8503618     Hamilton   https://www.imdb.com/title/tt8503618  2020
# 2294   tt4566758        Mulan   https://www.imdb.com/title/tt4566758  2020
# 2303  tt11681250  Godmothered  https://www.imdb.com/title/tt11681250  2020
#
#      Duration    MPA  Rating Votes       budget  grossWorldWide  ...  \
# 2007   1h 42m     PG     7.4  176K  175000000.0     141940042.0  ...
# 2067   1h 40m     PG     8.0  398K          NaN     121977511.0  ...
# 2274   2h 40m  PG-13     8.3  124K          NaN             NaN  ...
# 2294   1h 55m  PG-13     5.8  162K  200000000.0      69965374.0  ...
# 2303   1h 50m     PG     6.1   14K          NaN             NaN  ...
#
#                                               writers  \
# ...

# %% [markdown]
# ### consultar filmes a partir de 2020

# %%
df_year = df[df['Year'] >= 2020]
df_year.head()
# Out:
#              id                                              Title  \
# 2000  tt1502397                                  Bad Boys for Life
# 2001  tt8332922                              A Quiet Place Part II
# 2002  tt3794354                                 Sonic the Hedgehog
# 2003  tt7713068  Birds of Prey and the Fantabulous Emancipation...
# 2004  tt6673612                                           Dolittle
#
#                                 Movie Link  Year Duration    MPA  Rating  \
# 2000  https://www.imdb.com/title/tt1502397  2020    2h 4m      R     6.5
# 2001  https://www.imdb.com/title/tt8332922  2020   1h 37m  PG-13     7.2
# 2002  https://www.imdb.com/title/tt3794354  2020   1h 39m     PG     6.5
# 2003  https://www.imdb.com/title/tt7713068  2020   1h 49m      R     6.1
# 2004  https://www.imdb.com/title/tt6673612  2020   1h 41m     PG     5.6
#
#      Votes       budget  grossWorldWide  ...  \
# 2000  187K   90000000.0     426505244.0  ...
# ...

# %% [markdown]
# ### Consultar filmes a partir entre 2020 e 2024

# %%
df_year2 = df[df['Year'].between(2020, 2024)]
df_year2.head()
# Out:
#              id                                              Title  \
# 2000  tt1502397                                  Bad Boys for Life
# 2001  tt8332922                              A Quiet Place Part II
# 2002  tt3794354                                 Sonic the Hedgehog
# 2003  tt7713068  Birds of Prey and the Fantabulous Emancipation...
# 2004  tt6673612                                           Dolittle
#
#                                 Movie Link  Year Duration    MPA  Rating  \
# 2000  https://www.imdb.com/title/tt1502397  2020    2h 4m      R     6.5
# 2001  https://www.imdb.com/title/tt8332922  2020   1h 37m  PG-13     7.2
# 2002  https://www.imdb.com/title/tt3794354  2020   1h 39m     PG     6.5
# 2003  https://www.imdb.com/title/tt7713068  2020   1h 49m      R     6.1
# 2004  https://www.imdb.com/title/tt6673612  2020   1h 41m     PG     5.6
#
#      Votes       budget  grossWorldWide  ...  \
# 2000  187K   90000000.0     426505244.0  ...
# ...

# %% [markdown]
# ### Consultar filmes na lista de anos 2020,2021,2022,2023 e 2024

# %%
df_year3 = df[df['Year'].isin([2020,2021,2022,2023,2024])]
df_year3.head()
# Out:
#              id                                              Title  \
# 2000  tt1502397                                  Bad Boys for Life
# 2001  tt8332922                              A Quiet Place Part II
# 2002  tt3794354                                 Sonic the Hedgehog
# 2003  tt7713068  Birds of Prey and the Fantabulous Emancipation...
# 2004  tt6673612                                           Dolittle
#
#                                 Movie Link  Year Duration    MPA  Rating  \
# 2000  https://www.imdb.com/title/tt1502397  2020    2h 4m      R     6.5
# 2001  https://www.imdb.com/title/tt8332922  2020   1h 37m  PG-13     7.2
# 2002  https://www.imdb.com/title/tt3794354  2020   1h 39m     PG     6.5
# 2003  https://www.imdb.com/title/tt7713068  2020   1h 49m      R     6.1
# 2004  https://www.imdb.com/title/tt6673612  2020   1h 41m     PG     5.6
#
#      Votes       budget  grossWorldWide  ...  \
# 2000  187K   90000000.0     426505244.0  ...
# ...

# %%
# SELECT * from filmes_imdb fi
# where production_companies like '%Universal Pictures%'
# and countries_origin like '%United States%'
df_languages = df[df['Languages'].isin('English', case=False, na=False)]
df_languages.head()

# SELECT Title,"Year", Languages,Rating
# FROM filmes_imdb fi
# WHERE "Year" IN(2020,2021,2022,2023,2024)
# ORDER BY Rating
df_languages = df[df['Languages'].str.contains('English', case=False, na=False)]
df_languages.head()

# SELECT
# 	"Year",
# 	count(*) quantidade,
# 	sum(Rating) total_rating,
# 	avg(Rating) media_rating,
# 	ROUND(avg(Rating),2) media_formata
# FROM filmes_imdb fi
# WHERE "Year" IN(2020,2021,2022,2023,2024)
# GROUP BY "Year"
df_languages = df[df['Languages'].str.contains('English', case=False, na=False)]
df_languages.head()

# SELECT
# 	"Year",
# 	count(*) quantidade,
# 	sum(Rating) total_rating,
# 	avg(Rating) media_rating,
# 	ROUND(avg(Rating),2) media_formata
# FROM filmes_imdb fi
# WHERE "Year" NOT IN(2020,2021,2022,2023,2024)
# GROUP BY "Year"
df_languages = df[df['Languages'].str.contains('English', case=False, na=False)]
df_languages.head()

# SELECT
# 	budget,
# 	grossWorldWide,
# 	gross_US_Canada,
# 	(grossWorldWide + gross_US_Canada)  gross,
# 	ROUND( grossWorldWide / budget,2) as tickt
# FROM filmes_imdb fi
df_languages = df[df['Languages'].str.contains('English', case=False, na=False)]
df_languages.head()

# SELECT
# 	UPPER(title) maiusculo,
# 	LOWER(title) minusculo
# FROM filmes_imdb fi
df_languages = df[df['Languages'].str.contains('English', case=False, na=False)]
df_languages.head()

# SELECT * FROM filmes_imdb
# WHERE writers LIKE '%Varda%'

# -- Consultar filmes brasileiros lançados
# -- nos anos que teve Copa do Mundo
# SELECT * FROM filmes_imdb fi
# WHERE "Year" IN (
# 	SELECT DISTINCT YEAR
# 	FROM filmes_imdb
# 	WHERE ((YEAR+2)%4) = 0 --
# 	)
# AND countries_origin LIKE '%Brazil%'
df_languages = df[df['Languages'].str.contains('English', case=False, na=False)]
df_languages.head()



# SELECT
# 	fi.id,
# 	fi.stars,
# 	fi.genres,
# 	g.id,
# 	s.id
# FROM filmes_imdb fi
# INNER JOIN genres g ON fi.genres = g.genres
# INNER JOIN stars s ON fi.stars = s.stars
df_languages = df[df['Languages'].str.contains('English', case=False, na=False)]
df_languages.head()


# SELECT
# 	fi.id,
# 	fi.stars,
# 	fi.genres,
# 	g.id,
# 	s.id
# FROM filmes_imdb fi
# INNER JOIN genres g ON fi.genres = g.genres
# INNER JOIN stars s ON fi.stars = s.stars
df_languages = df[df['Languages'].str.contains('English', case=False, na=False)]
df_languages.head()


# SELECT
# DISTINCT genres
# FROM filmes_imdb
# WHERE genres IS NOT NULL
# AND genres <> "['Drama', 'Romance']"
df_languages = df[df['Languages'].str.contains('English', case=False, na=False)]
df_languages.head()


# /*
# Detalhes básicos do filme: título, ano, duração, classificação MPA, classificação IMDb, votos.
# Dados financeiros: Orçamento, bruto global, bruto dos EUA/Canadá, ganhos do fim de semana de abertura.
# Créditos: Diretores, roteiristas, estrelas.
# Detalhes adicionais: gêneros, países, locais de filmagem, produtoras, idiomas.
# Prêmios: Vitórias, indicações, indicações ao Oscar.
# */

# %%
# Fechar a conexão
conexao.close()

print("Dados importados com sucesso para o banco de dados SQLite.")
# Out:
# Dados importados com sucesso para o banco de dados SQLite.
